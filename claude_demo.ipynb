# %%
from utils import func_to_def, extract_function_calls, safer_eval, chat_completion_anthropic
from nexus_relational import *
import re
import pprint

# %%
functions = [
                get_user_info,
                get_location_info,
                get_food_info,
                get_user_name,
                list_user_ids,
                find_users_by_name,
                find_locations_by_name,
                find_foods_by_name,
                get_user_email,
                get_user_location,
                get_user_favorite_color,
                get_user_favorite_foods,
                get_weather_at_location,
                get_city_for_location,
                get_current_time_for_location,
                get_current_weather_for_location,
                get_food_name,
                get_food_calories,
                get_food_allergic_ingredients,
                get_current_user_id
            ]

# %%
functional_context = ""

for f in functions:
    functional_context += func_to_def(f) + "\n"

print(functional_context)
# Out:
# def get_user_info(id: int) -> dict -> dict:
#     """Find the user with the given user ID.
#
#     Args:
#         id: The user's ID.
#
#     Returns:
#         The user's data."""
#
# def get_location_info(id: int) -> dict -> dict:
#     """Find the location with the given location ID.
#
#     Args:
#         id: The location's ID.
#
#     Returns:
#         The location's data."""
#
# def get_food_info(food_id: int) -> dict -> dict:
#     """Find the food with the given food ID.
#
#     Args:
#         food_id: The food's ID.
#
#     Returns:
#         The food's data."""
#
# def get_user_name(user_id: int) -> str -> str:
#     """Get the name of the user with the given user ID.
#
#     Args:
#         user_id: The user's ID.
#
#     Returns:
#         The user's name."""
#
# def list_user_ids() -> List[str] -> List[str]:
#     """List all the user IDs."""
#
# def find_users_by_name(name: str):
#     """Find users with the given name.
#
#     Args:
# ...

# %%
with open("prompts/prompt1.txt") as fin:
    prompt = fin.read()

prompt = prompt.replace("{{FUNCTIONS}}", functional_context)
print(prompt)
# Out:
# You are an AI agent tasked with exploring a function calling environment. Your goal is to analyze the provided functions, understand their potential uses, and propose function calls to resolve any ambiguities or missing information. This process is similar to running unit tests to better understand the function calling environment.
#
# Here is the list of functions you have access to:
#
# <functions>
# def get_user_info(id: int) -> dict -> dict:
#     """Find the user with the given user ID.
#
#     Args:
#         id: The user's ID.
#
#     Returns:
#         The user's data."""
#
# def get_location_info(id: int) -> dict -> dict:
#     """Find the location with the given location ID.
#
#     Args:
#         id: The location's ID.
#
#     Returns:
#         The location's data."""
#
# def get_food_info(food_id: int) -> dict -> dict:
#     """Find the food with the given food ID.
#
#     Args:
#         food_id: The food's ID.
#
#     Returns:
#         The food's data."""
#
# ...

# %%
api_dict = {
    'api_key': '-'
}

conversation = []

prefix = "Here are the execution results:\n\n"

conversation.append(
    {
        'role': 'user',
        'content': prompt
    }
)
completion = chat_completion_anthropic("claude-3-5-sonnet-latest", conversation, 0.0, 8192, api_dict=api_dict)
print("="*20 + "Competion" + "="*20 + "\n")
print(completion)
raw_calls_str = re.findall(r'<function_list>(.*)</function_list>', completion, flags=re.DOTALL)[0].strip()
calls = extract_function_calls(raw_calls_str)
print("\n" + "="*20 + "Calls" + "="*20 + "\n")
print(calls)
print("\n" + "="*20 + "Call Outputs" + "="*20 + "\n")
context = vars() # you HAVE to do this here!
call_dict = dict((call, safer_eval(call, context=context)) for call in calls)
pprint.pprint(call_dict, sort_dicts=False)

conversation.append(
    {
        'role': 'assistant',
        'content': completion
    }
)

conversation.append(
    {
        'role': 'user',
        'content': prefix + str(call_dict)
    }
)
# Out:
# ====================Competion====================
#
# I'll analyze the functions and propose exploration calls. Here's my analysis and proposed calls:
#
# <exploration_summary>
# <function_analysis>
#
# 1. get_current_user_id()
# - Simple starting point as it takes no parameters
# - Will help establish context for other user-related calls
# - Proposed call: get_current_user_id()
# - Expected: Returns an integer ID of current user
#
# 2. get_user_info(id)
# - Takes user ID, returns dict with user details
# - Will help understand user data structure
# - Proposed call: get_user_info(1)
# - Expected: Dictionary containing user information
#
# 3. list_user_ids()
# - Returns list of all user IDs
# - Will help understand available test data
# - Proposed call: list_user_ids()
# - Expected: List of user ID strings/integers
#
# 4. find_users_by_name(name)
# - Search functionality for users
# - Proposed call: find_users_by_name("John")
# - Expected: List of matching users
#
# ...

# %%
completion = chat_completion_anthropic("claude-3-5-sonnet-latest", conversation, 0.0, 8192, api_dict=api_dict)
print("="*20 + "Competion" + "="*20 + "\n")
print(completion)
raw_calls_str = re.findall(r'<function_list>(.*)</function_list>', completion, flags=re.DOTALL)[0].strip()
calls = extract_function_calls(raw_calls_str)
print("\n" + "="*20 + "Calls" + "="*20 + "\n")
print(calls)
print("\n" + "="*20 + "Call Outputs" + "="*20 + "\n")
context = vars() # you HAVE to do this here!
call_dict = dict((call, safer_eval(call, context=context)) for call in calls)
pprint.pprint(call_dict, sort_dicts=False)

conversation.append(
    {
        'role': 'assistant',
        'content': completion
    }
)
conversation.append(
    {
        'role': 'user',
        'content': prefix + str(call_dict)
    }
)
# Out:
# ====================Competion====================
#
# Thank you for the results! Let me analyze these and propose additional calls to explore further.
#
# <exploration_summary>
# <function_analysis>
#
# Initial Findings:
# 1. Current context:
# - Current user ID is 35 (Charlie)
# - User IDs are integers
# - We have 6 users in the system (IDs: 1, 21, 35, 41, 42, 43)
#
# 2. Data Structures:
# User Info Structure:
# - Contains: id, name, email, location, favorite_color, favorite_foods
# - Example: Alice (ID 1) has complete profile
#
# Location Info Structure:
# - Contains: id, city, current_time, current_weather
# - Time and weather are live data
#
# Food Info Structure:
# - Contains: id, name, calories, allergic_ingredients
# - Includes nutritional and allergy information
#
# 3. Interesting observations:
# - find_users_by_name("John") returned all users but no "John"
# - Location data includes real-time information
# - Food items have detailed nutritional information
#
# ...

# %%
completion = chat_completion_anthropic("claude-3-5-sonnet-latest", conversation, 0.0, 8192, api_dict=api_dict)
print("="*20 + "Competion" + "="*20 + "\n")
print(completion)
raw_calls_str = re.findall(r'<function_list>(.*)</function_list>', completion, flags=re.DOTALL)[0].strip()
calls = extract_function_calls(raw_calls_str)
print("\n" + "="*20 + "Calls" + "="*20 + "\n")
print(calls)
print("\n" + "="*20 + "Call Outputs" + "="*20 + "\n")
context = vars() # you HAVE to do this here!
call_dict = dict((call, safer_eval(call, context=context)) for call in calls)
pprint.pprint(call_dict, sort_dicts=False)

conversation.append(
    {
        'role': 'assistant',
        'content': completion
    }
)
conversation.append(
    {
        'role': 'user',
        'content': prefix + str(call_dict)
    }
)
# Out:
# ====================Competion====================
#
# Excellent! Let me analyze these results and propose final exploration calls.
#
# <exploration_summary>
# <function_analysis>
#
# New Findings:
# 1. Current User (Charlie, ID 35):
# - Full profile confirmed
# - Location ID 3 (different from Alice's location 1)
# - Has different favorite foods [3, 7, 2]
# - Individual getters (name, email) match composite data
#
# 2. Location Functions:
# - Individual time/weather getters return identical format to composite data
# - Time format: "YYYY-MM-DD HH:MM AM/PM"
# - Weather format: "[Condition], Temperature: XX°F"
#
# 3. Food Information:
# - Food ID 2 is Chocolate
# - Calories are per serving (50)
# - Allergic ingredients are listed as array of strings
#
# Proposed final exploration calls:
#
# 1. Location comparison:
# - get_location_info(3) // Charlie's location
# - get_city_for_location(3) // Test city getter
#
# 2. Food chain completion:
# ...

# %%
completion = chat_completion_anthropic("claude-3-5-sonnet-latest", conversation, 0.0, 8192, api_dict=api_dict)
print("="*20 + "Competion" + "="*20 + "\n")
print(completion)

try:
    raw_calls_str = re.findall(r'<function_list>(.*)</function_list>', completion, flags=re.DOTALL)[0].strip()
    calls = extract_function_calls(raw_calls_str)
    print("\n" + "="*20 + "Calls" + "="*20 + "\n")
    print(calls)
    print("\n" + "="*20 + "Call Outputs" + "="*20 + "\n")
    context = vars() # you HAVE to do this here!
    call_dict = dict((call, safer_eval(call, context=context)) for call in calls)
    pprint.pprint(call_dict, sort_dicts=False)

    conversation.append(
        {
            'role': 'assistant',
            'content': completion
        }
    )
    conversation.append(
        {
            'role': 'user',
            'content': prefix + str(call_dict)
        }
    )
except Exception:
    conversation.append(
        {
            'role': 'assistant',
            'content': completion
        }
    )
    print("No function calls listed, move to next stage.")
# Out:
# ====================Competion====================
#
# Perfect! Now I can provide a complete analysis of the function calling environment.
#
# <exploration_summary>
# <function_analysis>
#
# Final System Analysis:
#
# 1. User System:
# - Users have complete profiles (id, name, email, location, favorite_color, favorite_foods)
# - Current user (Charlie, ID 35):
#   * Located in Chicago (location_id: 3)
#   * Favorite foods: Sushi, Salad, Chocolate
#   * Favorite color: yellow
#   * Email: charlie@yahoo.com
# - Individual getters match composite data perfectly
# - 6 users in system (IDs: 1, 21, 35, 41, 42, 43)
#
# 2. Location System:
# - Locations include real-time data (time and weather)
# - Different time zones supported (Chicago 11:15 AM vs New York 10:30 AM)
# - At least 5 cities in system: New York, Los Angeles, Chicago, Houston, Miami
# - Weather format consistent: "[Condition], Temperature: XX°F"
# - Time format consistent: "YYYY-MM-DD HH:MM AM/PM"
#
# 3. Food System:
# ...

# %%
final_prompt = """Now please update the function descriptions and/or return descriptions to clarify and disambiguate. This will ensure that future calls that do not have access to this conversation will still benefit from this exploration."""

conversation.append(
        {
            'role': 'user',
            'content': final_prompt
        }
    )

completion = chat_completion_anthropic("claude-3-5-sonnet-latest", conversation, 0.0, 8192, api_dict=api_dict)
print(completion)
# Out:
# Based on our exploration, here are the updated, more precise function descriptions:
#
# ```python
# def get_user_info(id: int) -> dict:
#     """Find the user with the given user ID.
#
#     Args:
#         id: The user's ID (integer).
#
#     Returns:
#         dict: User data containing:
#             - id (int): User ID
#             - name (str): User's full name
#             - email (str): User's email address
#             - location (int): User's location ID
#             - favorite_color (str): User's favorite color
#             - favorite_foods (List[int]): List of food IDs"""
#
# def get_location_info(id: int) -> dict:
#     """Find the location with the given location ID.
#
#     Args:
#         id: The location's ID (integer).
#
#     Returns:
#         dict: Location data containing:
#             - id (int): Location ID
#             - city (str): City name
#             - current_time (str): Current time in format 'YYYY-MM-DD HH:MM AM/PM'
# ...
